# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import warnings
#warnings.filterwarning("ignore")

# %%
csv_path = "data/gun-violence-data_01-2013_12-2015.csv"
gunviolence_df = pd.read_csv(csv_path)
gunviolence_df.head()
# Out:
#    incident_id    date           state city_or_county  \
# 0       461105  1/1/13    Pennsylvania     Mckeesport
# 1       460726  1/1/13      California      Hawthorne
# 2       478855  1/1/13            Ohio         Lorain
# 3       478925  1/5/13        Colorado         Aurora
# 4       478959  1/7/13  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
text = gunviolence_df.incident_characteristics[0]

# %%
wordcloud = WordCloud().generate(text)

# %%
wordcloud = WordCloud(width=1600, height=800).generate(text)
# Open a plot of the generated image.

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.savefig('images/final_wordcloud')
plt.show()

# %%
wordcloud = WordCloud(max_font_size=50, max_words=1000, background_color="black").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.savefig('images/output.png')
plt.show()

wordcloud = WordCloud(max_font_size= 200, max_words=1000, background_color="white", width=1600, height=800).generate(text)


plt.figure( figsize=(20,10), facecolor='k')
#plt.imshow(wordcloud)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.savefig('images/final_wordcloud')
plt.show()

# %% [markdown]
# # wordcloud.to_file("worldcloud.png")

# %%
gun_mask = np.array(Image.open("images/gun_mask1.png"))
gun_mask
# Out:
# array([[[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        ...,
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0]],
#
#        [[255, 255, 255,   0],
#         [255, 255, 255,   0],
#         [255, 255, 255,   0],
#         ...,
#         [255, 255, 255,   0],
# ...

# %%
gun_mask[gun_mask == 0] = 255

gun_mask

#arr.reshape((arr.shape[0], -1), order='F')
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
gun_mask = np.array(Image.open("images/gun_mask1.png"))

gun_mask = gun_mask.reshape((gun_mask.shape[0],-1), order='F')

# %%
def transform_format(val):
    if val == 0:
        return 255
    else:
        return val

# %%
transformed_gun_mask = np.ndarray((gun_mask.shape[0],gun_mask.shape[1]), np.int32)

for i in range(len(gun_mask)):
    transformed_gun_mask[i] = list(map(transform_format, gun_mask[i]))

# %%
wc = WordCloud(background_color="white", max_words=1000, mask=transformed_gun_mask,
                contour_width=3, contour_color='firebrick')

# %%
wc.generate(text)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     430                     font_size = int(2 * sizes[0] * sizes[1]
# --> 431                                     / (sizes[0] + sizes[1]))
#     432                 # quick fix for if self.layout_ contains less than 2 values
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     435                     try:
# --> 436                         font_size = sizes[0]
#     437                     except IndexError:
#
# IndexError: list index out of range
#
# ...

# %%
wc.to_file("gun_word_cloud.png")

# %%
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
